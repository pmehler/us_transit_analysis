# %% [markdown]
# # Plot census data using geopandas

# %%
# %matplotlib inline

import geopandas as gpd
from geopandas import GeoDataFrame

import pandas as pd
import contextily as ctx
import gtfs_kit as gk
import shapely
import rtree
import xarray as xr
from shapely.geometry import mapping
from shapely.ops import unary_union
import h3
import base64
import urllib
import tempfile
import networkx as nx
from csv import DictReader
from itertools import groupby
from tqdm import tqdm

import matplotlib.pyplot as plt
# Out:
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
zip_f = "nyc/tl_2020_36_tract.zip"

# %%
census_geo = gpd.read_file(zip_f)

# %%
census_geo.head(3)
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID NAME         NAMELSAD  MTFCC FUNCSTAT  \
# 0      36      047  000700  36047000700    7   Census Tract 7  G5020        S
# 1      36      047  000900  36047000900    9   Census Tract 9  G5020        S
# 2      36      047  001100  36047001100   11  Census Tract 11  G5020        S
#
#     ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0  176774       0  +40.6923505  -073.9973434
# 1  163469       0  +40.6917206  -073.9916018
# 2  168507       0  +40.6932903  -073.9877087
#
#                                             geometry
# 0  POLYGON ((-74.00154 40.69279, -74.00132 40.693...
# 1  POLYGON ((-73.99405 40.69090, -73.99374 40.691...
# 2  POLYGON ((-73.99073 40.69305, -73.99045 40.693...

# %%
commute = pd.read_csv('nyc/ny_commute_census_tract.csv')
commute = commute.drop(0,axis=0)

# %%
commute = commute.rename(columns={"FIPS": "GEOID"})

# %%
combined = census_geo.merge(commute, on='GEOID')

# %% [markdown]
# ## Examining the comuting census data

# %% [markdown]
# ## Examining the household census data

# %%
new_census = pd.read_csv('nyc/protected_attributes_ny_AMC2020_5year.csv', skiprows=[1])

# %%
census_df = pd.DataFrame()

# %%
pop_sex_columns = ["Total Population: Male",
                   "Total Population: Female",
                   "Total Population:"]
new_census[pop_sex_columns].info()
new_census[pop_sex_columns].head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5411 entries, 0 to 5410
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Total Population: Male    5411 non-null   int64
#  1   Total Population: Female  5411 non-null   int64
#  2   Total Population:         5411 non-null   int64
# dtypes: int64(3)
# memory usage: 126.9 KB
#    Total Population: Male  Total Population: Female  Total Population:
# 0                     890                      1139               2029
# 1                    1427                      1836               3263
# 2                    1059                      1094               2153
# 3                    1347                      1669               3016
# 4                    1287                      1644               2931

# %%
census_df["male_population"] = new_census["Total Population: Male"] 
census_df["female_population"] = new_census["Total Population: Female"]

# %%
census_df["total_population"] = new_census["Total Population:"]

# %%
census_df["total_population_white"] = new_census["Total Population: White Alone"] 
census_df["total_population_black"] = new_census["Total Population: Black or African American Alone"]
census_df["total_population_two_ormore_races"] = new_census["Total Population: Two or More Races"]
census_df["total_population_asian"] = new_census["Total Population: Asian Alone"]

# %%
census_df["population_over_25"] = new_census["Population 25 Years and Over:"]
census_df["population_over_25_no_highschool"] = new_census["Population 25 Years and Over: Less than High School"]
census_df["population_over_25_highschool"] = new_census["Population 25 Years and Over: High School Graduate (Includes Equivalency)"] 
census_df["population_over_25_bachelor"] = new_census["Population 25 Years and Over: Bachelor's Degree"]
census_df["population_over_25_master"] = new_census["Population 25 Years and Over: Master's Degree"]

# %%
census_df["households"] = new_census["Households:"]
census_df["households_0_to_50,000"] = new_census[["Households: Less than $10,000",
                                                    "Households: $10,000 to $14,999",
                                                    "Households: $15,000 to $19,999",
                                                    "Households: $20,000 to $24,999",
                                                    "Households: $25,000 to $29,999",
                                                    "Households: $30,000 to $34,999",
                                                    "Households: $35,000 to $39,999",
                                                    "Households: $40,000 to $44,999",
                                                    "Households: $45,000 to $49,999"]].sum(axis=1) 
census_df["households_over_50,000"] = new_census[["Households: $50,000 to $59,999",
                                                    "Households: $60,000 to $74,999",
                                                    "Households: $75,000 to $99,999",
                                                    "Households: $100,000 to $124,999",
                                                    "Households: $125,000 to $149,999",
                                                    "Households: $150,000 to $199,999",
                                                    "Households: $200,000 or More"]].sum(axis=1)

# %%
census_df["GEOID"] = new_census["FIPS"].astype(str)

# %%
census_df.head().T
# Out:
#                                              0            1            2  \
# male_population                            890         1427         1059
# female_population                         1139         1836         1094
# total_population                          2029         3263         2153
# total_population_white                     481          643           86
# total_population_black                    1141         2230         1968
# total_population_two_ormore_races          218          301           99
# total_population_asian                      99           89            0
# population_over_25                        1159         1906         1219
# population_over_25_no_highschool           251          239          150
# population_over_25_highschool              369          402          483
# population_over_25_bachelor                135          447           83
# population_over_25_master                   55           41           18
# households                                 769         1382          913
# households_0_to_50,000                     469          795          647
# households_over_50,000                     300          587          266
# GEOID                              36001000100  36001000201  36001000202
#
#                                              3            4
# male_population                           1347         1287
# female_population                         1669         1644
# total_population                          3016         2931
# total_population_white                     847         1936
# total_population_black                    1116          469
# total_population_two_ormore_races          581          209
# total_population_asian                     393          257
# population_over_25                        1805         2125
# population_over_25_no_highschool           352           92
# population_over_25_highschool              560          573
# population_over_25_bachelor                 43          300
# population_over_25_master                   92          431
# households                                1135         1585
# households_0_to_50,000                     943          913
# households_over_50,000                     192          672
# GEOID                              36001000301  36001000302

# %%
len(set(combined.GEOID))
# Out:
# 5411

# %%
census_df.shape
# Out:
# (5411, 16)

# %%
combined = combined.merge(census_df, on="GEOID")

# %%
combined.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5411 entries, 0 to 5410
# Columns: 103 entries, STATEFP to households_over_50,000
# dtypes: geometry(1), int64(17), object(85)
# memory usage: 4.3+ MB

# %% [markdown]
# # Normalising columns

# %%
import seaborn as sns

# %% [markdown]
# ```python
# corr_columns = ['Workers 16 Years and Over:',
#                 'Workers 16 Years and Over: Car, Truck, or Van',
#                 'Workers 16 Years and Over: Drove Alone',
#                 'Workers 16 Years and Over: Carpooled',
#                 'Workers 16 Years and Over: Public Transportation (Includes Taxicab)',
#                 'Workers 16 Years and Over: Motorcycle',
#                 'Workers 16 Years and Over: Bicycle',
#                 'Workers 16 Years and Over: Walked',
#                 'Workers 16 Years and Over: Other Means',
#                 'Workers 16 Years and Over: Worked At Home',
#                 'Workers 16 Years and Over:.1',
#                 'Workers 16 Years and Over: Did Not Work At Home',
#                 'Workers 16 Years and Over: Did Not Work At Home: Less than 10 Minutes',
#                 'Workers 16 Years and Over: Did Not Work At Home: 10 to 19 Minutes',
#                 'Workers 16 Years and Over: Did Not Work At Home: 20 to 29 Minutes',
#                 'Workers 16 Years and Over: Did Not Work At Home: 30 to 39 Minutes',
#                 'Workers 16 Years and Over: Did Not Work At Home: 40 to 59 Minutes',
#                 'Workers 16 Years and Over: Did Not Work At Home: 60 to 89 Minutes',
#                 'Workers 16 Years and Over: Did Not Work At Home: 90 or More Minutes',
#                 'Workers 16 Years and Over: Worked At Home.1',
#                 'Average Commute to Work (In Min)', 'total_population', 'male_population',"female_population"
#                 'total_population_white', 'total_population_black',
#                 'total_population_two_ormore_races', 'total_population_asian',
#                 'population_over_25', 'population_over_25_no_highschool',
#                 'population_over_25_highschool', 'population_over_25_bachelor',
#                 'population_over_25_master', 'households', 'households_0_to_50,000',
#                 'households_over_50,000']
# ````

# %%
transport_time_cols = ['Workers 16 Years and Over:',
       'Workers 16 Years and Over: Did Not Work At Home: Less than 10 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 10 to 19 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 20 to 29 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 30 to 39 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 40 to 59 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 60 to 89 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 90 or More Minutes']
combined["Workers 16 Years and Over:"] = combined["Workers 16 Years and Over:"].astype(int)
combined[transport_time_cols] = combined[transport_time_cols].astype(int)
combined[transport_time_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5411 entries, 0 to 5410
# Data columns (total 8 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Workers 16 Years and Over:                                             5411 non-null   int64
#  1   Workers 16 Years and Over: Did Not Work At Home: Less than 10 Minutes  5411 non-null   int64
#  2   Workers 16 Years and Over: Did Not Work At Home: 10 to 19 Minutes      5411 non-null   int64
#  3   Workers 16 Years and Over: Did Not Work At Home: 20 to 29 Minutes      5411 non-null   int64
#  4   Workers 16 Years and Over: Did Not Work At Home: 30 to 39 Minutes      5411 non-null   int64
#  5   Workers 16 Years and Over: Did Not Work At Home: 40 to 59 Minutes      5411 non-null   int64
#  6   Workers 16 Years and Over: Did Not Work At Home: 60 to 89 Minutes      5411 non-null   int64
#  7   Workers 16 Years and Over: Did Not Work At Home: 90 or More Minutes    5411 non-null   int64
# dtypes: int64(8)
# memory usage: 380.5 KB

# %%
combined["comute_time_less_30min"] = combined[[
       'Workers 16 Years and Over: Did Not Work At Home: Less than 10 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 10 to 19 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 20 to 29 Minutes']].sum(axis=1)/combined['Workers 16 Years and Over:']
combined["comute_time_more_30min"] = combined[['Workers 16 Years and Over: Did Not Work At Home: 30 to 39 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 40 to 59 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 60 to 89 Minutes',
       'Workers 16 Years and Over: Did Not Work At Home: 90 or More Minutes']].sum(axis=1)/combined['Workers 16 Years and Over:']
combined[["comute_time_less_30min", "comute_time_more_30min"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5411 entries, 0 to 5410
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   comute_time_less_30min  5285 non-null   float64
#  1   comute_time_more_30min  5285 non-null   float64
# dtypes: float64(2)
# memory usage: 126.8 KB

# %%
combined[["comute_time_less_30min", "comute_time_more_30min"]+ transport_time_cols].loc[combined[["comute_time_less_30min", "comute_time_more_30min"]].isna().any(axis=1)]
# Out:
#       comute_time_less_30min  comute_time_more_30min  \
# 38                       NaN                     NaN
# 68                       NaN                     NaN
# 127                      NaN                     NaN
# 133                      NaN                     NaN
# 405                      NaN                     NaN
# ...                      ...                     ...
# 5301                     NaN                     NaN
# 5307                     NaN                     NaN
# 5352                     NaN                     NaN
# 5369                     NaN                     NaN
# 5396                     NaN                     NaN
#
#       Workers 16 Years and Over:  \
# 38                             0
# 68                             0
# 127                            0
# 133                            0
# 405                            0
# ...                          ...
# 5301                           0
# 5307                           0
# 5352                           0
# 5369                           0
# 5396                           0
#
#       Workers 16 Years and Over: Did Not Work At Home: Less than 10 Minutes  \
# 38                                                    0
# 68                                                    0
# 127                                                   0
# 133                                                   0
# 405                                                   0
# ...                                                 ...
# 5301                                                  0
# 5307                                                  0
# 5352                                                  0
# 5369                                                  0
# 5396                                                  0
#
#       Workers 16 Years and Over: Did Not Work At Home: 10 to 19 Minutes  \
# 38                                                    0
# 68                                                    0
# 127                                                   0
# 133                                                   0
# 405                                                   0
# ...                                                 ...
# 5301                                                  0
# 5307                                                  0
# 5352                                                  0
# 5369                                                  0
# 5396                                                  0
#
#       Workers 16 Years and Over: Did Not Work At Home: 20 to 29 Minutes  \
# 38                                                    0
# 68                                                    0
# 127                                                   0
# 133                                                   0
# 405                                                   0
# ...                                                 ...
# 5301                                                  0
# 5307                                                  0
# 5352                                                  0
# 5369                                                  0
# 5396                                                  0
#
#       Workers 16 Years and Over: Did Not Work At Home: 30 to 39 Minutes  \
# 38                                                    0
# 68                                                    0
# 127                                                   0
# 133                                                   0
# 405                                                   0
# ...                                                 ...
# 5301                                                  0
# 5307                                                  0
# 5352                                                  0
# 5369                                                  0
# 5396                                                  0
#
#       Workers 16 Years and Over: Did Not Work At Home: 40 to 59 Minutes  \
# 38                                                    0
# 68                                                    0
# 127                                                   0
# 133                                                   0
# 405                                                   0
# ...                                                 ...
# 5301                                                  0
# 5307                                                  0
# 5352                                                  0
# 5369                                                  0
# 5396                                                  0
#
#       Workers 16 Years and Over: Did Not Work At Home: 60 to 89 Minutes  \
# 38                                                    0
# 68                                                    0
# 127                                                   0
# 133                                                   0
# 405                                                   0
# ...                                                 ...
# 5301                                                  0
# 5307                                                  0
# 5352                                                  0
# 5369                                                  0
# 5396                                                  0
#
#       Workers 16 Years and Over: Did Not Work At Home: 90 or More Minutes
# 38                                                    0
# 68                                                    0
# 127                                                   0
# 133                                                   0
# 405                                                   0
# ...                                                 ...
# 5301                                                  0
# 5307                                                  0
# 5352                                                  0
# 5369                                                  0
# 5396                                                  0
#
# [126 rows x 10 columns]

# %%
transport_cols = ['Workers 16 Years and Over:',
                'Workers 16 Years and Over: Car, Truck, or Van',
                'Workers 16 Years and Over: Drove Alone',
                'Workers 16 Years and Over: Carpooled',
                'Workers 16 Years and Over: Public Transportation (Includes Taxicab)',
                'Workers 16 Years and Over: Motorcycle',
                'Workers 16 Years and Over: Bicycle',
                'Workers 16 Years and Over: Walked',
                'Workers 16 Years and Over: Other Means',
                'Workers 16 Years and Over: Worked At Home']

combined[transport_cols] = combined[transport_cols].astype(int)
combined["over_16_puplictransportation"] = combined['Workers 16 Years and Over: Public Transportation (Includes Taxicab)'] /combined['Workers 16 Years and Over:']
combined["over_16_not_worked_home"] = combined['Workers 16 Years and Over: Worked At Home']/combined['Workers 16 Years and Over:']
combined["over_16_non_polution_transport"] = combined[['Workers 16 Years and Over: Bicycle','Workers 16 Years and Over: Walked']].sum(axis=1)/combined['Workers 16 Years and Over:']
combined["over_16_non_public_transport"] = combined[['Workers 16 Years and Over: Car, Truck, or Van',
                                                   'Workers 16 Years and Over: Drove Alone',
                                                   'Workers 16 Years and Over: Carpooled',
                                                   'Workers 16 Years and Over: Motorcycle',
                                                   'Workers 16 Years and Over: Other Means']].sum(axis=1) /combined['Workers 16 Years and Over:']

combined[["over_16_non_public_transport"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5411 entries, 0 to 5410
# Data columns (total 1 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   over_16_non_public_transport  5285 non-null   float64
# dtypes: float64(1)
# memory usage: 84.5 KB

# %%
population_cols = ['male_population',
               'total_population_white', 'total_population_black',
               'total_population_two_ormore_races', 'total_population_asian',"female_population"]


combined[population_cols] = combined[population_cols].div(combined["total_population"], axis=0)

# %%
# 25 year cols 
education_25_cols = ['population_over_25_no_highschool',
               'population_over_25_highschool', 'population_over_25_bachelor',
               'population_over_25_master']
combined[education_25_cols] = combined[education_25_cols].div(combined["population_over_25"], axis=0)

# %%
# Household cols
household_cols = [ 'households_0_to_50,000',
               'households_over_50,000']
combined[household_cols] = combined[household_cols].div(combined["households"], axis=0)

# %%
normalized_cols = ['Average Commute to Work (In Min)',"over_16_puplictransportation",
                "over_16_not_worked_home",
                "over_16_non_polution_transport",
                "over_16_non_public_transport",
                "comute_time_less_30min",
                "comute_time_more_30min",
                 'male_population',
               'total_population_white', 'total_population_black',
               'total_population_two_ormore_races', 'total_population_asian',"female_population",
                'population_over_25_no_highschool',
               'population_over_25_highschool', 'population_over_25_bachelor',
               'population_over_25_master', 'households_0_to_50,000',
               'households_over_50,000']
combined[normalized_cols].head().T
# Out:
#                                           0         1         2         3  \
# Average Commute to Work (In Min)         36        29        32        30
# over_16_puplictransportation       0.672611  0.651852  0.668067       0.5
# over_16_not_worked_home            0.138546  0.189198  0.126891   0.22973
# over_16_non_polution_transport     0.137631  0.128395   0.07395  0.179834
# over_16_non_public_transport       0.102423  0.053086  0.178992  0.180873
# comute_time_less_30min             0.280293  0.382716  0.372269  0.288981
# comute_time_more_30min             0.581161  0.428086   0.50084  0.481289
# male_population                    0.498846  0.485174  0.618509  0.518519
# total_population_white              0.84714  0.771594  0.701065  0.664058
# total_population_black             0.025391  0.038032  0.083222  0.104851
# total_population_two_ormore_races  0.089254  0.084658  0.037949  0.061033
# total_population_asian             0.023083  0.100774  0.152463  0.127804
# female_population                  0.501154  0.514826  0.381491  0.481481
# population_over_25_no_highschool   0.024372  0.023425    0.0086  0.013977
# population_over_25_highschool      0.050564  0.025848  0.046912  0.121982
# population_over_25_bachelor        0.415424  0.439688  0.454261   0.24587
# population_over_25_master          0.264824  0.272213  0.261142  0.343075
# households_0_to_50,000             0.158179  0.071804  0.110024  0.287953
# households_over_50,000             0.841821  0.928196  0.889976  0.712047
#
#                                           4
# Average Commute to Work (In Min)         39
# over_16_puplictransportation       0.606947
# over_16_not_worked_home                 0.0
# over_16_non_polution_transport     0.268739
# over_16_non_public_transport       0.248629
# comute_time_less_30min             0.268739
# comute_time_more_30min             0.731261
# male_population                    0.480373
# total_population_white              0.40652
# total_population_black             0.027279
# total_population_two_ormore_races  0.007319
# total_population_asian             0.060546
# female_population                  0.519627
# population_over_25_no_highschool   0.520651
# population_over_25_highschool      0.272841
# population_over_25_bachelor        0.162703
# population_over_25_master               0.0
# households_0_to_50,000              0.57732
# households_over_50,000              0.42268

# %%
combined[normalized_cols].describe().T
# Out:
#                                     count      mean       std  min       25%  \
# over_16_puplictransportation       5285.0  0.258915  0.258707  0.0  0.017826
# over_16_not_worked_home            5285.0  0.066065  0.057600  0.0  0.027451
# over_16_non_polution_transport     5285.0  0.066541  0.091792  0.0  0.010899
# over_16_non_public_transport       5285.0  1.208817  0.608961  0.0  0.632536
# comute_time_less_30min             5285.0  0.461728  0.223362  0.0  0.264269
# comute_time_more_30min             5285.0  0.472207  0.223623  0.0  0.286746
# male_population                    5304.0  0.487676  0.060849  0.0  0.459979
# total_population_white             5304.0  0.624016  0.311514  0.0  0.352384
# total_population_black             5304.0  0.160862  0.236322  0.0  0.010671
# total_population_two_ormore_races  5304.0  0.045851  0.042526  0.0  0.015366
# total_population_asian             5304.0  0.085211  0.134339  0.0  0.006409
# female_population                  5304.0  0.512324  0.060849  0.0  0.486891
# population_over_25_no_highschool   5300.0  0.131409  0.104790  0.0  0.055143
# population_over_25_highschool      5300.0  0.263792  0.107806  0.0  0.194739
# population_over_25_bachelor        5300.0  0.200792  0.099827  0.0  0.127893
# population_over_25_master          5300.0  0.112414  0.073788  0.0  0.056637
# households_0_to_50,000             5264.0  0.374811  0.179807  0.0  0.238095
# households_over_50,000             5264.0  0.625189  0.179807  0.0  0.518630
#
#                                         50%       75%       max
# over_16_puplictransportation       0.158192  0.496970  1.000000
# over_16_not_worked_home            0.053740  0.090563  1.000000
# over_16_non_polution_transport     0.035889  0.085126  0.833333
# over_16_non_public_transport       1.400913  1.767589  2.000000
# comute_time_less_30min             0.448780  0.647541  1.000000
# comute_time_more_30min             0.474557  0.668775  1.000000
# male_population                    0.487006  0.513109  1.000000
# total_population_white             0.724652  0.902031  1.000000
# total_population_black             0.045819  0.198446  1.000000
# total_population_two_ormore_races  0.034288  0.064145  0.480000
# total_population_asian             0.031541  0.096986  1.000000
# female_population                  0.512994  0.540021  1.000000
# population_over_25_no_highschool   0.101717  0.179549  1.000000
# population_over_25_highschool      0.266896  0.336155  1.000000
# population_over_25_bachelor        0.188422  0.261231  1.000000
# population_over_25_master          0.098326  0.157275  0.597723
# households_0_to_50,000             0.352734  0.481370  1.000000
# households_over_50,000             0.647266  0.761905  1.000000

# %%
combined[normalized_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5411 entries, 0 to 5410
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Average Commute to Work (In Min)   5256 non-null   object
#  1   over_16_puplictransportation       5285 non-null   float64
#  2   over_16_not_worked_home            5285 non-null   float64
#  3   over_16_non_polution_transport     5285 non-null   float64
#  4   over_16_non_public_transport       5285 non-null   float64
#  5   comute_time_less_30min             5285 non-null   float64
#  6   comute_time_more_30min             5285 non-null   float64
#  7   male_population                    5304 non-null   float64
#  8   total_population_white             5304 non-null   float64
#  9   total_population_black             5304 non-null   float64
#  10  total_population_two_ormore_races  5304 non-null   float64
#  11  total_population_asian             5304 non-null   float64
#  12  female_population                  5304 non-null   float64
#  13  population_over_25_no_highschool   5300 non-null   float64
#  14  population_over_25_highschool      5300 non-null   float64
#  15  population_over_25_bachelor        5300 non-null   float64
#  16  population_over_25_master          5300 non-null   float64
#  17  households_0_to_50,000             5264 non-null   float64
#  18  households_over_50,000             5264 non-null   float64
# dtypes: float64(18), object(1)
# memory usage: 845.5+ KB

# %%
combined[normalized_cols].loc[combined[normalized_cols].isna().all(axis=1)]
# Out:
#      Average Commute to Work (In Min)  over_16_puplictransportation  \
# 38                                NaN                           NaN
# 68                                NaN                           NaN
# 127                               NaN                           NaN
# 133                               NaN                           NaN
# 561                               NaN                           NaN
# ...                               ...                           ...
# 5301                              NaN                           NaN
# 5307                              NaN                           NaN
# 5352                              NaN                           NaN
# 5369                              NaN                           NaN
# 5396                              NaN                           NaN
#
#       over_16_not_worked_home  over_16_non_polution_transport  \
# 38                        NaN                             NaN
# 68                        NaN                             NaN
# 127                       NaN                             NaN
# 133                       NaN                             NaN
# 561                       NaN                             NaN
# ...                       ...                             ...
# 5301                      NaN                             NaN
# 5307                      NaN                             NaN
# 5352                      NaN                             NaN
# 5369                      NaN                             NaN
# 5396                      NaN                             NaN
#
#       over_16_non_public_transport  comute_time_less_30min  \
# 38                             NaN                     NaN
# 68                             NaN                     NaN
# 127                            NaN                     NaN
# 133                            NaN                     NaN
# 561                            NaN                     NaN
# ...                            ...                     ...
# 5301                           NaN                     NaN
# 5307                           NaN                     NaN
# 5352                           NaN                     NaN
# 5369                           NaN                     NaN
# 5396                           NaN                     NaN
#
#       comute_time_more_30min  male_population  total_population_white  \
# 38                       NaN              NaN                     NaN
# 68                       NaN              NaN                     NaN
# 127                      NaN              NaN                     NaN
# 133                      NaN              NaN                     NaN
# 561                      NaN              NaN                     NaN
# ...                      ...              ...                     ...
# 5301                     NaN              NaN                     NaN
# 5307                     NaN              NaN                     NaN
# 5352                     NaN              NaN                     NaN
# 5369                     NaN              NaN                     NaN
# 5396                     NaN              NaN                     NaN
#
#       total_population_black  total_population_two_ormore_races  \
# 38                       NaN                                NaN
# 68                       NaN                                NaN
# 127                      NaN                                NaN
# 133                      NaN                                NaN
# 561                      NaN                                NaN
# ...                      ...                                ...
# 5301                     NaN                                NaN
# 5307                     NaN                                NaN
# 5352                     NaN                                NaN
# 5369                     NaN                                NaN
# 5396                     NaN                                NaN
#
#       total_population_asian  female_population  \
# 38                       NaN                NaN
# 68                       NaN                NaN
# 127                      NaN                NaN
# 133                      NaN                NaN
# 561                      NaN                NaN
# ...                      ...                ...
# 5301                     NaN                NaN
# 5307                     NaN                NaN
# 5352                     NaN                NaN
# 5369                     NaN                NaN
# 5396                     NaN                NaN
#
#       population_over_25_no_highschool  population_over_25_highschool  \
# 38                                 NaN                            NaN
# 68                                 NaN                            NaN
# 127                                NaN                            NaN
# 133                                NaN                            NaN
# 561                                NaN                            NaN
# ...                                ...                            ...
# 5301                               NaN                            NaN
# 5307                               NaN                            NaN
# 5352                               NaN                            NaN
# 5369                               NaN                            NaN
# 5396                               NaN                            NaN
#
#       population_over_25_bachelor  population_over_25_master  \
# 38                            NaN                        NaN
# 68                            NaN                        NaN
# 127                           NaN                        NaN
# 133                           NaN                        NaN
# 561                           NaN                        NaN
# ...                           ...                        ...
# 5301                          NaN                        NaN
# 5307                          NaN                        NaN
# 5352                          NaN                        NaN
# 5369                          NaN                        NaN
# 5396                          NaN                        NaN
#
#       households_0_to_50,000  households_over_50,000
# 38                       NaN                     NaN
# 68                       NaN                     NaN
# 127                      NaN                     NaN
# 133                      NaN                     NaN
# 561                      NaN                     NaN
# ...                      ...                     ...
# 5301                     NaN                     NaN
# 5307                     NaN                     NaN
# 5352                     NaN                     NaN
# 5369                     NaN                     NaN
# 5396                     NaN                     NaN
#
# [107 rows x 19 columns]

# %%
combined[normalized_cols].loc[combined[normalized_cols].isna().all(axis=1)]
# Out:
#      Average Commute to Work (In Min)  over_16_puplictransportation  \
# 38                                NaN                           NaN
# 68                                NaN                           NaN
# 127                               NaN                           NaN
# 133                               NaN                           NaN
# 561                               NaN                           NaN
# ...                               ...                           ...
# 5301                              NaN                           NaN
# 5307                              NaN                           NaN
# 5352                              NaN                           NaN
# 5369                              NaN                           NaN
# 5396                              NaN                           NaN
#
#       over_16_not_worked_home  over_16_non_polution_transport  \
# 38                        NaN                             NaN
# 68                        NaN                             NaN
# 127                       NaN                             NaN
# 133                       NaN                             NaN
# 561                       NaN                             NaN
# ...                       ...                             ...
# 5301                      NaN                             NaN
# 5307                      NaN                             NaN
# 5352                      NaN                             NaN
# 5369                      NaN                             NaN
# 5396                      NaN                             NaN
#
#       over_16_non_public_transport  comute_time_less_30min  \
# 38                             NaN                     NaN
# 68                             NaN                     NaN
# 127                            NaN                     NaN
# 133                            NaN                     NaN
# 561                            NaN                     NaN
# ...                            ...                     ...
# 5301                           NaN                     NaN
# 5307                           NaN                     NaN
# 5352                           NaN                     NaN
# 5369                           NaN                     NaN
# 5396                           NaN                     NaN
#
#       comute_time_more_30min  male_population  total_population_white  \
# 38                       NaN              NaN                     NaN
# 68                       NaN              NaN                     NaN
# 127                      NaN              NaN                     NaN
# 133                      NaN              NaN                     NaN
# 561                      NaN              NaN                     NaN
# ...                      ...              ...                     ...
# 5301                     NaN              NaN                     NaN
# 5307                     NaN              NaN                     NaN
# 5352                     NaN              NaN                     NaN
# 5369                     NaN              NaN                     NaN
# 5396                     NaN              NaN                     NaN
#
#       total_population_black  total_population_two_ormore_races  \
# 38                       NaN                                NaN
# 68                       NaN                                NaN
# 127                      NaN                                NaN
# 133                      NaN                                NaN
# 561                      NaN                                NaN
# ...                      ...                                ...
# 5301                     NaN                                NaN
# 5307                     NaN                                NaN
# 5352                     NaN                                NaN
# 5369                     NaN                                NaN
# 5396                     NaN                                NaN
#
#       total_population_asian  female_population  \
# 38                       NaN                NaN
# 68                       NaN                NaN
# 127                      NaN                NaN
# 133                      NaN                NaN
# 561                      NaN                NaN
# ...                      ...                ...
# 5301                     NaN                NaN
# 5307                     NaN                NaN
# 5352                     NaN                NaN
# 5369                     NaN                NaN
# 5396                     NaN                NaN
#
#       population_over_25_no_highschool  population_over_25_highschool  \
# 38                                 NaN                            NaN
# 68                                 NaN                            NaN
# 127                                NaN                            NaN
# 133                                NaN                            NaN
# 561                                NaN                            NaN
# ...                                ...                            ...
# 5301                               NaN                            NaN
# 5307                               NaN                            NaN
# 5352                               NaN                            NaN
# 5369                               NaN                            NaN
# 5396                               NaN                            NaN
#
#       population_over_25_bachelor  population_over_25_master  \
# 38                            NaN                        NaN
# 68                            NaN                        NaN
# 127                           NaN                        NaN
# 133                           NaN                        NaN
# 561                           NaN                        NaN
# ...                           ...                        ...
# 5301                          NaN                        NaN
# 5307                          NaN                        NaN
# 5352                          NaN                        NaN
# 5369                          NaN                        NaN
# 5396                          NaN                        NaN
#
#       households_0_to_50,000  households_over_50,000
# 38                       NaN                     NaN
# 68                       NaN                     NaN
# 127                      NaN                     NaN
# 133                      NaN                     NaN
# 561                      NaN                     NaN
# ...                      ...                     ...
# 5301                     NaN                     NaN
# 5307                     NaN                     NaN
# 5352                     NaN                     NaN
# 5369                     NaN                     NaN
# 5396                     NaN                     NaN
#
# [107 rows x 19 columns]

# %%
combined[normalized_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5411 entries, 0 to 5410
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Average Commute to Work (In Min)   5256 non-null   object
#  1   over_16_puplictransportation       5285 non-null   float64
#  2   over_16_not_worked_home            5285 non-null   float64
#  3   over_16_non_polution_transport     5285 non-null   float64
#  4   over_16_non_public_transport       5285 non-null   float64
#  5   comute_time_less_30min             5285 non-null   float64
#  6   comute_time_more_30min             5285 non-null   float64
#  7   male_population                    5304 non-null   float64
#  8   total_population_white             5304 non-null   float64
#  9   total_population_black             5304 non-null   float64
#  10  total_population_two_ormore_races  5304 non-null   float64
#  11  total_population_asian             5304 non-null   float64
#  12  female_population                  5304 non-null   float64
#  13  population_over_25_no_highschool   5300 non-null   float64
#  14  population_over_25_highschool      5300 non-null   float64
#  15  population_over_25_bachelor        5300 non-null   float64
#  16  population_over_25_master          5300 non-null   float64
#  17  households_0_to_50,000             5264 non-null   float64
#  18  households_over_50,000             5264 non-null   float64
# dtypes: float64(18), object(1)
# memory usage: 845.5+ KB

# %%
combined[normalized_cols] = combined[normalized_cols].loc[~combined[normalized_cols].isna().any(axis=1)]

# %%
combined.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID NAME         NAMELSAD  MTFCC FUNCSTAT  \
# 0      36      047  000700  36047000700    7   Census Tract 7  G5020        S
# 1      36      047  000900  36047000900    9   Census Tract 9  G5020        S
# 2      36      047  001100  36047001100   11  Census Tract 11  G5020        S
# 3      36      047  001300  36047001300   13  Census Tract 13  G5020        S
# 4      36      047  002000  36047002000   20  Census Tract 20  G5020        S
#
#     ALAND  AWATER  ... population_over_25_master households  \
# 0  176774       0  ...                  0.264824       1669
# 1  163469       0  ...                  0.272213       2284
# 2  168507       0  ...                  0.261142        818
# 3  293167       0  ...                  0.343075       1021
# 4  154138       0  ...                  0.000000        388
#
#   households_0_to_50,000 households_over_50,000 comute_time_less_30min  \
# 0               0.158179               0.841821               0.280293
# 1               0.071804               0.928196               0.382716
# 2               0.110024               0.889976               0.372269
# 3               0.287953               0.712047               0.288981
# 4               0.577320               0.422680               0.268739
#
#   comute_time_more_30min over_16_puplictransportation over_16_not_worked_home  \
# 0               0.581161                     0.672611                0.138546
# 1               0.428086                     0.651852                0.189198
# 2               0.500840                     0.668067                0.126891
# 3               0.481289                     0.500000                0.229730
# 4               0.731261                     0.606947                0.000000
#
#   over_16_non_polution_transport over_16_non_public_transport
# 0                       0.137631                     0.102423
# 1                       0.128395                     0.053086
# 2                       0.073950                     0.178992
# 3                       0.179834                     0.180873
# 4                       0.268739                     0.248629
#
# [5 rows x 109 columns]

# %%
combined['over_16_puplictransportation'].describe()
# Out:
# count    5241.000000
# mean        0.258806
# std         0.257479
# min         0.000000
# 25%         0.018153
# 50%         0.159873
# 75%         0.496673
# max         0.925049
# Name: over_16_puplictransportation, dtype: float64

# %%
fig, ax = plt.subplots(1, figsize=(12,12))
corr = combined[normalized_cols].corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %%
import scipy
import scipy.cluster.hierarchy as sch
import numpy as np

def cluster_corr(corr_array, inplace=False):
    """
    Rearranges the correlation matrix, corr_array, so that groups of highly 
    correlated variables are next to eachother 
    
    Parameters
    ----------
    corr_array : pandas.DataFrame or numpy.ndarray
        a NxN correlation matrix 
        
    Returns
    -------
    pandas.DataFrame or numpy.ndarray
        a NxN correlation matrix with the columns and rows rearranged
    """
    pairwise_distances = sch.distance.pdist(corr_array)
    linkage = sch.linkage(pairwise_distances, method='complete')
    cluster_distance_threshold = pairwise_distances.max()/2
    idx_to_cluster_array = sch.fcluster(linkage, cluster_distance_threshold, 
                                        criterion='distance')
    idx = np.argsort(idx_to_cluster_array)
    
    if not inplace:
        corr_array = corr_array.copy()
    
    if isinstance(corr_array, pd.DataFrame):
        return corr_array.iloc[idx, :].T.iloc[idx, :]
    return corr_array[idx, :][:, idx]

# %%
fig, ax = plt.subplots(1, figsize=(12,12))

sns.heatmap(cluster_corr(combined[normalized_cols].corr()))
# Out:
# <AxesSubplot:>

# %%
combined = combined.to_crs("EPSG:4326")
combined.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Loading the stops

# %%
def get_stop_id(stop_id):
    """ translate stop_id to parent_stop_id 
        if available
    """
    if 'parent_station' not in STOPS[stop_id].keys():
        return stop_id
    elif STOPS[stop_id]['parent_station'] == '':
        return stop_id
    else:
        try:
            if np.isnan(STOPS[stop_id]['parent_station']):
                return stop_id
            else:
                STOPS[stop_id]['parent_station']
        except:
            return STOPS[stop_id]['parent_station']


def add_stop_to_graph(G, stop_id):
    """ add stop as new node to graph
    """
    #lookup details of the stop (parent stop if available)
    node = STOPS[get_stop_id(stop_id)]

    if node['stop_id'] not in G.nodes:
        G.add_node(node['stop_id'], 
                   stop_name = node['stop_name'], 
                   stop_lon = node['stop_lon'], 
                   stop_lat = node['stop_lat'])
    return G

def add_edge_to_graph(G, from_id, to_id, route_short_name):
    """ add edge to graph 
        adding the route short name as a key
        if the edge and key exist, increment the count
    """
    edge = G.get_edge_data(get_stop_id(from_id), get_stop_id(to_id),route_short_name, default = 0)
    if edge == 0:
        G.add_edge(get_stop_id(from_id), get_stop_id(to_id), 
                   key=route_short_name,
                   count=1)
    else:
        G.add_edge(get_stop_id(from_id), get_stop_id(to_id), 
                   key=route_short_name,
                   count=edge['count']+1)
        
def get_stops_from_gtfs(path):
    feed = (gk.read_feed(path, dist_units='km'))
    return feed

def kring_smoothing(df, hex_col, metric_col, k):
    dfk = df[[hex_col]] 
    dfk.index = dfk[hex_col]
    dfs =  (dfk[hex_col]
                 .apply(lambda x: pd.Series(list(h3.k_ring(x,k)))).stack()
                 .to_frame('hexk').reset_index(1, drop=True).reset_index()
                 .merge(df[[hex_col,metric_col]]).fillna(0)
                 .groupby(['hexk'])[[metric_col]].sum().divide((1 + 3 * k * (k + 1)))
                 .reset_index()
                 .rename(index=str, columns={"hexk": hex_col}))
    dfs['lat'] = dfs[hex_col].apply(lambda x: h3.h3_to_geo(x)[0])
    dfs['lon'] = dfs[hex_col].apply(lambda x: h3.h3_to_geo(x)[1]) 
    return dfs

# %%
DATA_ROOT='nyc/gtfs_zips/nyc_ferry.zip'
TRIPS_FILE = f'{DATA_ROOT}trips.txt'
ROUTES_FILE = f'{DATA_ROOT}routes.txt'
STOPS_FILE = f'{DATA_ROOT}stops.txt'

INCLUDE_AGENCIES=['MTA NYCT']
IGNORE_ROUTE=[]


# put all gtfs zips in one directory

# assign directory
directory = 'nyc/gtfs_zips/'
files = gk.list_feed(directory)
files=files[files['file_name'].str.contains('.zip')]['file_name']
files = directory+files

# %%
files
# Out:
# 0         nyc/gtfs_zips/mta_brooklyn_gtfs.zip
# 1            nyc/gtfs_zips/mta_bronx_gtfs.zip
# 2        nyc/gtfs_zips/mta_manhattan_gtfs.zip
# 3               nyc/gtfs_zips/subway_gtfs.zip
# 4           nyc/gtfs_zips/mta_queens_gtfs.zip
# 5                 nyc/gtfs_zips/nyc_ferry.zip
# 6      nyc/gtfs_zips/long_island_railroad.zip
# 7    nyc/gtfs_zips/mta_staten_island_gtfs.zip
# 8          nyc/gtfs_zips/metro_north_gtfs.zip
# Name: file_name, dtype: object

# %%
def generate_all_dfs(files):
    
    feed = (gk.read_feed(files[0], dist_units='km'))
    STOPS, ROUTES, TRIPS, stop_times = generate_sub_gtfs_dfs(feed)
    
    for i in range(1,len(files)):
        feed = (gk.read_feed(files[i], dist_units='km'))
        temp_STOPS, temp_ROUTES, temp_TRIPS, temp_stop_times = generate_sub_gtfs_dfs(feed)
        
        stop_times = pd.concat([stop_times, temp_stop_times])
        
        STOPS.update(temp_STOPS)
        ROUTES.update(temp_ROUTES)
        TRIPS.update(temp_TRIPS)
        
    
    return STOPS, ROUTES, TRIPS, stop_times, feed

# %%
def generate_sub_gtfs_dfs(feed):
    STOPS = feed.get_stops().set_index('stop_id').to_dict('index')

    for key in STOPS.keys():
        STOPS[key]['stop_id'] = key
        
    ROUTES = feed.get_routes().set_index('route_id').to_dict('index')

    for key in ROUTES.keys():
        ROUTES[key]['route_id'] = key

    TRIPS = feed.get_trips().set_index('trip_id').to_dict('index')

    for key in TRIPS.keys():
        TRIPS[key]['route_short_name'] = ROUTES[TRIPS[key]['route_id']]['route_short_name']
        TRIPS[key]['trip_id'] = key
        
    stop_times = feed.get_stop_times()
    
    return STOPS, ROUTES, TRIPS, stop_times

# %%
STOPS, ROUTES, TRIPS, stop_times, feed = generate_all_dfs(files)

# %%
# sort just to be sure
# didn't actually check that there are no repeated trip_ids across public transport types
sorted_stops = stop_times.sort_values(['trip_id', 'stop_sequence'], ascending=[True, True])

# %%
# rewrote using numpy array to increase speed significantly
trip_ids = sorted_stops['trip_id'].to_numpy()
stops_ids = sorted_stops['stop_id'].to_numpy()

# %%
stops = set()
edges = dict()

# build network
next_trip = trip_ids[1]
for i in tqdm(range(len(stops_ids)-1)):
    if trip_ids[i] in TRIPS:
        trip = TRIPS[trip_ids[i]]
        # if we are still on the same route, create edges
        if trip_ids[i]==next_trip:
            stop = stops_ids[i]
            stops.add(stop)
            next_stop = stops_ids[i+1]
            edge = (stop, next_stop)
            edges[edge] = trip['route_short_name']
        # we start a new route
        else:
            stop = stops_ids[i]
            stops.add(stop)
        
        if i < len(stops_ids)-2:
            next_trip=trip_ids[i+2]
        else:
            next_trip = -1
        
# add the final stop to the list
stops.add(next_stop)
# Out:
# 100%|█████████████████████████████| 7976512/7976512 [00:11<00:00, 694522.53it/s]

# %%
G = nx.MultiGraph()

# %%
print ('stops', len(stops))
print ('edges', len(edges))

for stop_id in STOPS:
    if stop_id in stops:
        add_stop_to_graph(G, stop_id)
        
print('Nodes:', G.number_of_nodes() )
        
for (start_stop_id, end_stop_id), route_short_name in edges.items():
    if start_stop_id==end_stop_id:
        print(start_stop_id, end_stop_id, route_short_name)
    add_edge_to_graph(G, 
                      from_id = start_stop_id, 
                      to_id = end_stop_id, 
                      route_short_name=route_short_name)
print('Edges:', G.number_of_edges() )



deg = nx.degree(G)
labels = {stop_id: G.nodes[stop_id]['stop_name'] if deg[stop_id] >= 0 else ''
          for stop_id in G.nodes}

pos = {stop_id: (G.nodes[stop_id]['stop_lon'], G.nodes[stop_id]['stop_lat'])
       for stop_id in G.nodes}
# Out:
# stops 13713
# edges 16507
# Nodes: 13166
# Edges: 15580

# %%
G_simple = nx.Graph(G)

# %%
btw = nx.betweenness_centrality(G_simple)

# %%
# create scaled betweenness dictionary

l=np.zeros(len(btw))
keys=list(btw.keys())

for i in range(len(btw)):
    l[i]=btw[keys[i]]
    
# linear scale factor for betweenness
scale = (9/np.max(l))

for key in btw.keys():
    btw[key] = (btw[key]*scale)+1

# %%
nx.set_node_attributes(G_simple, btw, "betweenness")

# %%
# wrangle betweenness to df with coordinates
df_btw = pd.DataFrame.from_dict(btw, orient='index')
df_btw.columns=['betweenness']

betweenness_geo = df_btw.join(pd.DataFrame.from_dict(pos, orient='index'))
betweenness_geo.columns = ['betweenness','lon','lat']

# %%
# using number of departures as a frequency proxy 
betweenness_geo = betweenness_geo.join(
    stop_times['stop_id'].value_counts()).rename(
    columns={'stop_id':'num_departures'})

# arbitrarily set the scale to be 2.5,  This says frequency is about 25% as important as betweenness
scale = (2.5/betweenness_geo['num_departures'].max())

betweenness_geo['num_departures_scaled'] = (betweenness_geo['num_departures']*scale)+1

# %%
# FIND LIT FOR THIS, ARBITRARY FUNCTION
# create accessibility score
betweenness_geo['accessibility_score'] = \
    betweenness_geo['num_departures_scaled']+betweenness_geo['betweenness']

# %%
betweenness_geo.plot.scatter(x='betweenness',y='num_departures_scaled')
# Out:
# <AxesSubplot:xlabel='betweenness', ylabel='num_departures_scaled'>

# %%
# we need to get route type for each stop to do the k-ring calc
temp_r = pd.DataFrame.from_dict(ROUTES, orient='index')[['route_type','route_id']]
temp_r = pd.DataFrame.from_dict(TRIPS, orient='index')[['route_id','trip_id']].merge(temp_r, on='route_id')
stop_times = stop_times.merge(temp_r, on='trip_id')

# %%
betweenness_geo = betweenness_geo.join(stop_times[['stop_id','route_type']].set_index('stop_id'))

# %%
APERTURE_SIZE = 9
hex_col = 'hex'+str(APERTURE_SIZE)
metric_col = 'accessibility_score'

# find hexs containing the points
betweenness_geo[hex_col] = betweenness_geo.apply(lambda x: h3.geo_to_h3(x.lat,x.lon,APERTURE_SIZE),1)

# sum accessibility grouped by route type and hex
hex_df = pd.DataFrame(
    betweenness_geo.groupby([hex_col,'route_type'])[metric_col].agg('sum')).reset_index()

# %%
#find center of hex for visualization
hex_df['stop_lat'] = hex_df[hex_col].apply(lambda x: h3.h3_to_geo(x)[0])
hex_df['stop_lon'] = hex_df[hex_col].apply(lambda x: h3.h3_to_geo(x)[1])

# %%
mapping={ # h3_resolution: {transport type : num_k_rings}
    8:{1:2, 2:2, 3:1, 4:2},
    9:{1:5, 2:5, 3:3, 4:5},
    10:{1:12, 2:12, 3:7, 4:12}
}

# %%
k_ring_all_types = pd.DataFrame(columns=[hex_col, 'accessibility_score', 'lat','lon'])                            
grouped_hex = hex_df.groupby('route_type')
for key, value in grouped_hex: 
    k_ring_all_types = pd.concat([k_ring_all_types,
        kring_smoothing(value, hex_col, metric_col=metric_col, k=mapping[APERTURE_SIZE][key])])

# %%
# sum all layers of smoothed route types
k_ring_all_types = k_ring_all_types.groupby([hex_col])['accessibility_score'].agg('sum').reset_index()
#find center of hex for visualization
k_ring_all_types['lat'] = k_ring_all_types[hex_col].apply(lambda x: h3.h3_to_geo(x)[0])
k_ring_all_types['lon'] = k_ring_all_types[hex_col].apply(lambda x: h3.h3_to_geo(x)[1])

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))

# pltot the hexs
k_ring_all_types.plot.scatter(ax=ax, x='lon', y='lat', c=metric_col,
                    edgecolors='none', colormap='viridis', marker='o', figsize=(17,15));
plt.xticks([], []); plt.yticks([], [])
plt.title('subway stops: 2-ring average');

ctx.add_basemap(ax=ax, crs="EPSG:4326")

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))

gdf = combined.loc[combined.COUNTYFP.isin(["081", "005", "047", "085", "061", "103", "059", "087", "119", "079", "071","027"])].copy()
ax = k_ring_all_types.plot.scatter(ax=ax, x='lon', y='lat', c=metric_col,
                    edgecolors='none', colormap='viridis', marker='o', figsize=(17,15));
gdf.plot(ax=ax)

plt.show()

# %% [markdown]
# ## Spatial analysis

# %%
#gdf = combined.loc[combined.COUNTYFP.isin(["081", "005", "047", "085", "061"])].copy()
gdf = combined.loc[combined.COUNTYFP.isin(["081", "005", "047", "085", "061", "103", "059", "087", "119", "079", "071","027"])].copy()
gdf = gdf.to_crs("EPSG:4326")

METRIC_COL = "over_16_non_public_transport"
# Drop row with nan METRIC
gdf = gdf.loc[~gdf[METRIC_COL].isna()]

# %%
sgdf = gpd.GeoDataFrame(hex_df, geometry=gpd.points_from_xy(hex_df.stop_lon, hex_df.stop_lat), crs=gdf.crs)
sgdf.head()
# Out:
#               hex9  route_type  accessibility_score   stop_lat   stop_lon  \
# 0  892a1000063ffff         3.0          1777.491899  40.852911 -73.790314
# 1  892a1000067ffff         3.0           884.615479  40.850321 -73.788079
# 2  892a100007bffff         3.0          1340.689528  40.855501 -73.792549
# 3  892a1000243ffff         3.0          3833.874011  40.860027 -73.822736
# 4  892a100024bffff         3.0          1329.818973  40.859918 -73.827021
#
#                      geometry
# 0  POINT (-73.79031 40.85291)
# 1  POINT (-73.78808 40.85032)
# 2  POINT (-73.79255 40.85550)
# 3  POINT (-73.82274 40.86003)
# 4  POINT (-73.82702 40.85992)

# %%
accessibility_metric = "accessibility_score"
gdf = sgdf[[accessibility_metric, "geometry"]].sjoin(gdf, how="right", predicate='intersects').drop(columns=["index_left"]).fillna(0)

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 5152 entries, 0 to 5410
# Columns: 110 entries, accessibility_score to over_16_non_public_transport
# dtypes: float64(19), geometry(1), int64(65), object(25)
# memory usage: 4.4+ MB

# %%
gdf.head().T
# Out:
#                                           0             1             2  \
# accessibility_score             6852.803169  10457.932164  12606.839514
# STATEFP                                  36            36            36
# COUNTYFP                                047           047           047
# TRACTCE                              000700        000900        001100
# GEOID                           36047000700   36047000900   36047001100
# ...                                     ...           ...           ...
# comute_time_more_30min             0.581161      0.428086       0.50084
# over_16_puplictransportation       0.672611      0.651852      0.668067
# over_16_not_worked_home            0.138546      0.189198      0.126891
# over_16_non_polution_transport     0.137631      0.128395       0.07395
# over_16_non_public_transport       0.102423      0.053086      0.178992
#
#                                           2            2
# accessibility_score             34449.76076  2110.840364
# STATEFP                                  36           36
# COUNTYFP                                047          047
# TRACTCE                              001100       001100
# GEOID                           36047001100  36047001100
# ...                                     ...          ...
# comute_time_more_30min              0.50084      0.50084
# over_16_puplictransportation       0.668067     0.668067
# over_16_not_worked_home            0.126891     0.126891
# over_16_non_polution_transport      0.07395      0.07395
# over_16_non_public_transport       0.178992     0.178992
#
# [110 rows x 5 columns]

# %% [markdown]
# ## Modelling

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

# %%
gdf.columns
# Out:
# Index(['accessibility_score', 'STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID',
#        'NAME', 'NAMELSAD', 'MTFCC', 'FUNCSTAT', 'ALAND',
#        ...
#        'population_over_25_master', 'households', 'households_0_to_50,000',
#        'households_over_50,000', 'comute_time_less_30min',
#        'comute_time_more_30min', 'over_16_puplictransportation',
#        'over_16_not_worked_home', 'over_16_non_polution_transport',
#        'over_16_non_public_transport'],
#       dtype='object', length=110)

# %%
feature_col = [accessibility_metric, 'Average Commute to Work (In Min)',
       'over_16_puplictransportation', 'over_16_not_worked_home',
       'over_16_non_polution_transport', 'over_16_non_public_transport',
       'comute_time_less_30min', 'comute_time_more_30min', 'male_population',
       'total_population_white', 'total_population_black',
       'total_population_two_ormore_races', 'total_population_asian',
       'female_population', 'population_over_25_no_highschool',
       'population_over_25_highschool', 'population_over_25_bachelor',
       'population_over_25_master', 'households_0_to_50,000',
       'households_over_50,000']
target_col = 'over_16_puplictransportation'
feature_col = np.array([col for col in feature_col if col not in [target_col]])

# %%
regression_df = gdf[feature_col.tolist()+[target_col]].copy()
#regression_df['Average Commute to Work (In Min)'] = regression_df['Average Commute to Work (In Min)'].fillna("0").astype(float)

# %%
regression_df[f"log_{accessibility_metric}"] = np.log(regression_df[accessibility_metric]+1)

# %%
regression_df[accessibility_metric].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
regression_df[f"log_{accessibility_metric}"].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
feature_col= np.append(feature_col,f"log_{accessibility_metric}")

# %%
feature_col
# Out:
# array(['accessibility_score', 'Average Commute to Work (In Min)',
#        'over_16_not_worked_home', 'over_16_non_polution_transport',
#        'over_16_non_public_transport', 'comute_time_less_30min',
#        'comute_time_more_30min', 'male_population',
#        'total_population_white', 'total_population_black',
#        'total_population_two_ormore_races', 'total_population_asian',
#        'female_population', 'population_over_25_no_highschool',
#        'population_over_25_highschool', 'population_over_25_bachelor',
#        'population_over_25_master', 'households_0_to_50,000',
#        'households_over_50,000', 'log_accessibility_score'], dtype='<U33')

# %%
regression_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5152 entries, 0 to 5410
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   accessibility_score                5152 non-null   float64
#  1   Average Commute to Work (In Min)   5152 non-null   object
#  2   over_16_not_worked_home            5152 non-null   float64
#  3   over_16_non_polution_transport     5152 non-null   float64
#  4   over_16_non_public_transport       5152 non-null   float64
#  5   comute_time_less_30min             5152 non-null   float64
#  6   comute_time_more_30min             5152 non-null   float64
#  7   male_population                    5152 non-null   float64
#  8   total_population_white             5152 non-null   float64
#  9   total_population_black             5152 non-null   float64
#  10  total_population_two_ormore_races  5152 non-null   float64
#  11  total_population_asian             5152 non-null   float64
#  12  female_population                  5152 non-null   float64
#  13  population_over_25_no_highschool   5152 non-null   float64
#  14  population_over_25_highschool      5152 non-null   float64
#  15  population_over_25_bachelor        5152 non-null   float64
#  16  population_over_25_master          5152 non-null   float64
#  17  households_0_to_50,000             5152 non-null   float64
#  18  households_over_50,000             5152 non-null   float64
#  19  over_16_puplictransportation       5152 non-null   float64
#  20  log_accessibility_score            5152 non-null   float64
# dtypes: float64(20), object(1)
# memory usage: 885.5+ KB

# %%
regression_df.describe()
# Out:
#        accessibility_score  over_16_not_worked_home  \
# count          5152.000000              5152.000000
# mean           2556.186035                 0.067026
# std            3986.116369                 0.054783
# min               0.000000                 0.000000
# 25%               0.000000                 0.025417
# 50%            1393.381000                 0.054281
# 75%            3474.846563                 0.094761
# max           85289.172438                 0.555556
#
#        over_16_non_polution_transport  over_16_non_public_transport  \
# count                     5152.000000                   5152.000000
# mean                         0.077109                      0.907550
# std                          0.092477                      0.535266
# min                          0.000000                      0.000000
# 25%                          0.015927                      0.404362
# 50%                          0.048392                      0.918990
# 75%                          0.101520                      1.361942
# max                          0.782857                      2.000000
#
#        comute_time_less_30min  comute_time_more_30min  male_population  \
# count             5152.000000             5152.000000      5152.000000
# mean                 0.327032                0.605942         0.481773
# std                  0.144019                0.155372         0.050381
# min                  0.015539                0.026316         0.149007
# 25%                  0.216148                0.502044         0.454784
# 50%                  0.301417                0.630597         0.483841
# 75%                  0.421826                0.723204         0.509688
# max                  0.869660                0.984461         1.000000
#
#        total_population_white  total_population_black  \
# count             5152.000000             5152.000000
# mean                 0.506057                0.206887
# std                  0.299401                0.264832
# min                  0.000000                0.000000
# 25%                  0.225458                0.017761
# 50%                  0.529607                0.073834
# 75%                  0.775547                0.312156
# max                  1.000000                0.995649
#
#        total_population_two_ormore_races  total_population_asian  \
# count                        5152.000000             5152.000000
# mean                            0.049725                0.123118
# std                             0.042326                0.154968
# min                             0.000000                0.000000
# 25%                             0.018339                0.020868
# 50%                             0.040011                0.063817
# 75%                             0.070494                0.161096
# max                             0.357479                0.939405
#
#        female_population  population_over_25_no_highschool  \
# count        5152.000000                       5152.000000
# mean            0.518227                          0.148837
# std             0.050381                          0.107310
# min             0.000000                          0.000000
# 25%             0.490312                          0.066821
# 50%             0.516159                          0.123428
# 75%             0.545216                          0.208696
# max             0.850993                          0.676218
#
#        population_over_25_highschool  population_over_25_bachelor  \
# count                    5152.000000                  5152.000000
# mean                        0.247381                     0.218970
# std                         0.101134                     0.098696
# min                         0.000000                     0.000000
# 25%                         0.184186                     0.147557
# 50%                         0.254286                     0.207899
# 75%                         0.314662                     0.276513
# max                         0.644867                     0.612537
#
#        population_over_25_master  households_0_to_50,000  \
# count                5152.000000             5152.000000
# mean                    0.118305                0.349835
# std                     0.075109                0.173514
# min                     0.000000                0.000000
# 25%                     0.061990                0.222154
# 50%                     0.106053                0.315470
# 75%                     0.161700                0.449367
# max                     0.597723                0.950000
#
#        households_over_50,000  over_16_puplictransportation  \
# count             5152.000000                   5152.000000
# mean                 0.650165                      0.398114
# std                  0.173514                      0.222158
# min                  0.050000                      0.000000
# 25%                  0.550633                      0.207807
# 50%                  0.684530                      0.406089
# 75%                  0.777846                      0.589747
# max                  1.000000                      0.925049
#
#        log_accessibility_score
# count              5152.000000
# mean                  5.307527
# std                   3.700159
# min                   0.000000
# 25%                   0.000000
# 50%                   7.240205
# 75%                   8.153593
# max                  11.353815

# %%
fig, ax = plt.subplots(1, figsize=(12,12))

sns.heatmap(cluster_corr(regression_df.corr()))
# Out:
# <AxesSubplot:>

# %%
kf = KFold(n_splits=5)

X = regression_df[feature_col]
y = regression_df[target_col].values

# %%
plt.hist(y, bins=30)
plt.show()
print(np.array(y).mean(),np.array(y).std())
# Out:
# 0.3981138092009333 0.22213666920868

# %%
feature_col
# Out:
# array(['accessibility_score', 'Average Commute to Work (In Min)',
#        'over_16_not_worked_home', 'over_16_non_polution_transport',
#        'over_16_non_public_transport', 'comute_time_less_30min',
#        'comute_time_more_30min', 'male_population',
#        'total_population_white', 'total_population_black',
#        'total_population_two_ormore_races', 'total_population_asian',
#        'female_population', 'population_over_25_no_highschool',
#        'population_over_25_highschool', 'population_over_25_bachelor',
#        'population_over_25_master', 'households_0_to_50,000',
#        'households_over_50,000', 'log_accessibility_score'], dtype='<U33')

# %%
X.head()
# Out:
#    accessibility_score Average Commute to Work (In Min)  \
# 0          6852.803169                               36
# 1         10457.932164                               29
# 2         12606.839514                               32
# 2         34449.760760                               32
# 2          2110.840364                               32
#
#    over_16_not_worked_home  over_16_non_polution_transport  \
# 0                 0.138546                        0.137631
# 1                 0.189198                        0.128395
# 2                 0.126891                        0.073950
# 2                 0.126891                        0.073950
# 2                 0.126891                        0.073950
#
#    over_16_non_public_transport  comute_time_less_30min  \
# 0                      0.102423                0.280293
# 1                      0.053086                0.382716
# 2                      0.178992                0.372269
# 2                      0.178992                0.372269
# 2                      0.178992                0.372269
#
#    comute_time_more_30min  male_population  total_population_white  \
# 0                0.581161         0.498846                0.847140
# 1                0.428086         0.485174                0.771594
# 2                0.500840         0.618509                0.701065
# 2                0.500840         0.618509                0.701065
# 2                0.500840         0.618509                0.701065
#
#    total_population_black  total_population_two_ormore_races  \
# 0                0.025391                           0.089254
# 1                0.038032                           0.084658
# 2                0.083222                           0.037949
# 2                0.083222                           0.037949
# 2                0.083222                           0.037949
#
#    total_population_asian  female_population  \
# 0                0.023083           0.501154
# 1                0.100774           0.514826
# 2                0.152463           0.381491
# 2                0.152463           0.381491
# 2                0.152463           0.381491
#
#    population_over_25_no_highschool  population_over_25_highschool  \
# 0                          0.024372                       0.050564
# 1                          0.023425                       0.025848
# 2                          0.008600                       0.046912
# 2                          0.008600                       0.046912
# 2                          0.008600                       0.046912
#
#    population_over_25_bachelor  population_over_25_master  \
# 0                     0.415424                   0.264824
# 1                     0.439688                   0.272213
# 2                     0.454261                   0.261142
# 2                     0.454261                   0.261142
# 2                     0.454261                   0.261142
#
#    households_0_to_50,000  households_over_50,000  log_accessibility_score
# 0                0.158179                0.841821                 8.832559
# 1                0.071804                0.928196                 9.255212
# 2                0.110024                0.889976                 9.442074
# 2                0.110024                0.889976                10.447286
# 2                0.110024                0.889976                 7.655315

# %%
preds = np.zeros(len(y))
coefs = np.zeros(len(X.columns))
for train_index, test_index in kf.split(regression_df):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y[train_index], y[test_index]
    scaler = StandardScaler()
    scaler = scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    reg = Ridge().fit(X_train_scaled, y_train)
    coefs += reg.coef_
    preds[test_index] = reg.predict(X_test_scaled)

coefs /= 5

# %%
idx = np.argsort(coefs)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))
ax[0].barh(feature_col[idx],coefs[idx])

ax[1].scatter(y, preds, alpha=0.6)
ax[1].plot([i for i in range(2)])
plt.show()
mean_squared_error(y, preds, squared=False), r2_score(y, preds)
# Out:
# (0.007489532844298861, 0.9988632395688882)

# %%
feature_col =  np.array([col for col in feature_col if col not in ['over_16_non_public_transport', 'over_16_non_polution_transport']])

kf = KFold(n_splits=5)

X = regression_df[feature_col].values
y = regression_df[target_col].values
preds = np.zeros(len(y))
coefs = np.zeros(len(feature_col))
for train_index, test_index in kf.split(regression_df):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    scaler = StandardScaler()
    scaler = scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    reg = Ridge().fit(X_train_scaled, y_train)
    coefs += reg.coef_
    preds[test_index] = reg.predict(X_test_scaled)

coefs /= 5

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))
idx = np.argsort(coefs)
ax[0].barh(feature_col[idx],coefs[idx])

ax[1].scatter(y, preds, alpha=0.6)
ax[1].plot([i for i in range(2)])
plt.show()
mean_squared_error(y, preds, squared=False), r2_score(y, preds)
# Out:
# (0.11710370287110762, 0.7220921947093466)

# %%
feature_col
# Out:
# array(['accessibility_score', 'Average Commute to Work (In Min)',
#        'over_16_not_worked_home', 'comute_time_less_30min',
#        'comute_time_more_30min', 'male_population',
#        'total_population_white', 'total_population_black',
#        'total_population_two_ormore_races', 'total_population_asian',
#        'female_population', 'population_over_25_no_highschool',
#        'population_over_25_highschool', 'population_over_25_bachelor',
#        'population_over_25_master', 'households_0_to_50,000',
#        'households_over_50,000', 'log_accessibility_score'], dtype='<U33')

# %%
feature_col =  np.array([col for col in feature_col if col not in ['over_16_non_public_transport', 'over_16_non_polution_transport', 'comute_time_less_30min', 'Average Commute to Work (In Min)', 'over_16_not_worked_home', 'comute_time_more_30min']])

kf = KFold(n_splits=5)

X = regression_df[feature_col].values
y = regression_df[target_col].values
preds = np.zeros(len(y))
coefs = np.zeros(len(feature_col))
for train_index, test_index in kf.split(regression_df):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    scaler = StandardScaler()
    scaler = scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    reg = Ridge().fit(X_train_scaled, y_train)
    coefs += reg.coef_
    preds[test_index] = reg.predict(X_test_scaled)

coefs /= 5

# %%
mse, r2 = mean_squared_error(y, preds, squared=False), r2_score(y, preds)

print(f"MSE:{mse}")
print(f"R^2 (coefficient of determination) regression score function.: {r2}")
fig, ax = plt.subplots(1,2, figsize=(10,8))
idx = np.argsort(coefs)

ax[0].set_title("Model weights")
ax[0].barh(feature_col[idx],coefs[idx])
ax[0].set_xlabel("Feature coefficient")

points = ax[1].scatter(y, preds, alpha=0.6, c = regression_df[f"log_{accessibility_metric}"])
ax[1].set_title("Ratio of people using public transport\nPredticed vs. True scores")
ax[1].plot([x for x in range(2)])
ax[1].set_xlabel("Predicted value")
ax[1].set_ylabel("True value")

plt.colorbar(points,ax=ax[1], label="Log accessibility score")

plt.show()
# Out:
# MSE:0.14735591812293797
# R^2 (coefficient of determination) regression score function.: 0.5599574687711845

# %% [markdown]
# # Visualizing the results

# %%
#Functions
def plot_scatter(df, metric_col, x='lng', y='lat', marker='.', alpha=1, figsize=(16,12), colormap='viridis', basemap=None, ax=None):  
    if not ax:
        fig, ax = plt.subplots(1, 1, figsize=figsize)
    df.plot.scatter(ax=ax, x=x, y=y, c="white", title=metric_col
                    , edgecolors='none', marker=marker, alpha=alpha, figsize=figsize);
    if basemap:
        ctx.add_basemap(ax=ax, crs=basemap)

    plt.xticks([], []); plt.yticks([], [])
    return ax

# %%
# Visualize Population Density per Census Tract
f, ax = plt.subplots(figsize=(14,14))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# ax = plot_scatter(stopsg, metric_col='cnt', y="stop_lat", x="stop_lon", marker='o', basemap=gdf.crs.to_string(),ax=ax)
gdf["Prediction_diff"] = y - preds
ax = gdf.plot(column="Prediction_diff",cmap='viridis',alpha=1,linewidth=0.05,ax=ax, legend=True)
ax = hex_df.plot.scatter(ax=ax, y="stop_lat", x="stop_lon", marker="o", color="black", alpha=.1, edgecolors='none')

plt.title('Prediction error')
# Out:
# Text(0.5, 1.0, 'Prediction error')

# %%
# Visualize Population Density per Census Tract
f, ax = plt.subplots(figsize=(14,14))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# ax = plot_scatter(stopsg, metric_col='cnt', y="stop_lat", x="stop_lon", marker='o', basemap=gdf.crs.to_string(),ax=ax)
gdf["Prediction_diff"] = y - preds
ax = gdf.plot(column="Prediction_diff",cmap='viridis',alpha=1,linewidth=0.05,ax=ax, legend=True)

plt.title('Prediction error')
# Out:
# Text(0.5, 1.0, 'Prediction error')

# %% [markdown]
# ## Modelling

# %%
gdf = combined.loc[combined.COUNTYFP.isin(["081", "005", "047", "085", "061"])].copy()
gdf = gdf.to_crs("EPSG:4326")

METRIC_COL = "over_16_non_public_transport"
# Drop row with nan METRIC
gdf = gdf.loc[~gdf[METRIC_COL].isna()]

# %%
sgdf = gpd.GeoDataFrame(hex_df, geometry=gpd.points_from_xy(hex_df.stop_lon, hex_df.stop_lat), crs=gdf.crs)
sgdf.head()
# Out:
#               hex9  route_type  accessibility_score   stop_lat   stop_lon  \
# 0  892a1000063ffff         3.0          1777.491899  40.852911 -73.790314
# 1  892a1000067ffff         3.0           884.615479  40.850321 -73.788079
# 2  892a100007bffff         3.0          1340.689528  40.855501 -73.792549
# 3  892a1000243ffff         3.0          3833.874011  40.860027 -73.822736
# 4  892a100024bffff         3.0          1329.818973  40.859918 -73.827021
#
#                      geometry
# 0  POINT (-73.79031 40.85291)
# 1  POINT (-73.78808 40.85032)
# 2  POINT (-73.79255 40.85550)
# 3  POINT (-73.82274 40.86003)
# 4  POINT (-73.82702 40.85992)

# %%
accessibility_metric = "accessibility_score"
gdf = sgdf[[accessibility_metric, "geometry"]].sjoin(gdf, how="right", predicate='intersects').drop(columns=["index_left"]).fillna(0)

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3925 entries, 0 to 5410
# Columns: 110 entries, accessibility_score to over_16_non_public_transport
# dtypes: float64(19), geometry(1), int64(65), object(25)
# memory usage: 3.3+ MB

# %%
gdf.head().T
# Out:
#                                           0             1             2  \
# accessibility_score             6852.803169  10457.932164  12606.839514
# STATEFP                                  36            36            36
# COUNTYFP                                047           047           047
# TRACTCE                              000700        000900        001100
# GEOID                           36047000700   36047000900   36047001100
# ...                                     ...           ...           ...
# comute_time_more_30min             0.581161      0.428086       0.50084
# over_16_puplictransportation       0.672611      0.651852      0.668067
# over_16_not_worked_home            0.138546      0.189198      0.126891
# over_16_non_polution_transport     0.137631      0.128395       0.07395
# over_16_non_public_transport       0.102423      0.053086      0.178992
#
#                                           2            2
# accessibility_score             34449.76076  2110.840364
# STATEFP                                  36           36
# COUNTYFP                                047          047
# TRACTCE                              001100       001100
# GEOID                           36047001100  36047001100
# ...                                     ...          ...
# comute_time_more_30min              0.50084      0.50084
# over_16_puplictransportation       0.668067     0.668067
# over_16_not_worked_home            0.126891     0.126891
# over_16_non_polution_transport      0.07395      0.07395
# over_16_non_public_transport       0.178992     0.178992
#
# [110 rows x 5 columns]

# %%
feature_col = [accessibility_metric, 'Average Commute to Work (In Min)',
       'over_16_puplictransportation', 'over_16_not_worked_home',
       'over_16_non_polution_transport', 'over_16_non_public_transport',
       'comute_time_less_30min', 'comute_time_more_30min', 'male_population',
       'total_population_white', 'total_population_black',
       'total_population_two_ormore_races', 'total_population_asian',
       'female_population', 'population_over_25_no_highschool',
       'population_over_25_highschool', 'population_over_25_bachelor',
       'population_over_25_master', 'households_0_to_50,000',
       'households_over_50,000']
target_col = 'over_16_puplictransportation'
feature_col = np.array([col for col in feature_col if col not in [target_col]])

# %%
regression_df = gdf[feature_col.tolist()+[target_col]].copy()
#regression_df['Average Commute to Work (In Min)'] = regression_df['Average Commute to Work (In Min)'].fillna("0").astype(float)

# %%
regression_df[f"log_{accessibility_metric}"] = np.log(regression_df[accessibility_metric]+1)

# %%
regression_df[accessibility_metric].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
regression_df[f"log_{accessibility_metric}"].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
feature_col= np.append(feature_col,f"log_{accessibility_metric}")

# %%
feature_col
# Out:
# array(['accessibility_score', 'Average Commute to Work (In Min)',
#        'over_16_not_worked_home', 'over_16_non_polution_transport',
#        'over_16_non_public_transport', 'comute_time_less_30min',
#        'comute_time_more_30min', 'male_population',
#        'total_population_white', 'total_population_black',
#        'total_population_two_ormore_races', 'total_population_asian',
#        'female_population', 'population_over_25_no_highschool',
#        'population_over_25_highschool', 'population_over_25_bachelor',
#        'population_over_25_master', 'households_0_to_50,000',
#        'households_over_50,000', 'log_accessibility_score'], dtype='<U33')

# %%
regression_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3925 entries, 0 to 5410
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   accessibility_score                3925 non-null   float64
#  1   Average Commute to Work (In Min)   3925 non-null   object
#  2   over_16_not_worked_home            3925 non-null   float64
#  3   over_16_non_polution_transport     3925 non-null   float64
#  4   over_16_non_public_transport       3925 non-null   float64
#  5   comute_time_less_30min             3925 non-null   float64
#  6   comute_time_more_30min             3925 non-null   float64
#  7   male_population                    3925 non-null   float64
#  8   total_population_white             3925 non-null   float64
#  9   total_population_black             3925 non-null   float64
#  10  total_population_two_ormore_races  3925 non-null   float64
#  11  total_population_asian             3925 non-null   float64
#  12  female_population                  3925 non-null   float64
#  13  population_over_25_no_highschool   3925 non-null   float64
#  14  population_over_25_highschool      3925 non-null   float64
#  15  population_over_25_bachelor        3925 non-null   float64
#  16  population_over_25_master          3925 non-null   float64
#  17  households_0_to_50,000             3925 non-null   float64
#  18  households_over_50,000             3925 non-null   float64
#  19  over_16_puplictransportation       3925 non-null   float64
#  20  log_accessibility_score            3925 non-null   float64
# dtypes: float64(20), object(1)
# memory usage: 674.6+ KB

# %%
regression_df.describe()
# Out:
#        accessibility_score  over_16_not_worked_home  \
# count          3925.000000              3925.000000
# mean           3241.815476                 0.065274
# std            4253.490697                 0.054616
# min               0.000000                 0.000000
# 25%             819.441984                 0.023923
# 50%            2116.758844                 0.051554
# 75%            4238.668490                 0.093023
# max           85289.172438                 0.384615
#
#        over_16_non_polution_transport  over_16_non_public_transport  \
# count                     3925.000000                   3925.000000
# mean                         0.091220                      0.713085
# std                          0.097135                      0.440856
# min                          0.000000                      0.000000
# 25%                          0.026291                      0.327251
# 50%                          0.064870                      0.640244
# 75%                          0.115699                      1.087500
# max                          0.698499                      2.000000
#
#        comute_time_less_30min  comute_time_more_30min  male_population  \
# count             3925.000000             3925.000000      3925.000000
# mean                 0.281429                0.653297         0.479456
# std                  0.119894                0.135851         0.051795
# min                  0.015539                0.091405         0.250991
# 25%                  0.195628                0.584780         0.450838
# 50%                  0.260000                0.672840         0.482137
# 75%                  0.350453                0.747859         0.508259
# max                  0.860846                0.984461         1.000000
#
#        total_population_white  total_population_black  \
# count             3925.000000             3925.000000
# mean                 0.441721                0.237775
# std                  0.290269                0.283868
# min                  0.000000                0.000000
# 25%                  0.172691                0.019667
# 50%                  0.424732                0.089188
# 75%                  0.701065                0.399537
# max                  1.000000                0.995649
#
#        total_population_two_ormore_races  total_population_asian  \
# count                        3925.000000             3925.000000
# mean                            0.051287                0.143010
# std                             0.042507                0.168132
# min                             0.000000                0.000000
# 25%                             0.019544                0.024623
# 50%                             0.042053                0.077222
# 75%                             0.072343                0.197501
# max                             0.357479                0.939405
#
#        female_population  population_over_25_no_highschool  \
# count        3925.000000                       3925.000000
# mean            0.520544                          0.164316
# std             0.051795                          0.107513
# min             0.000000                          0.000000
# 25%             0.491741                          0.083624
# 50%             0.517863                          0.144360
# 75%             0.549162                          0.228848
# max             0.749009                          0.659232
#
#        population_over_25_highschool  population_over_25_bachelor  \
# count                    3925.000000                  3925.000000
# mean                        0.251565                     0.217066
# std                         0.103190                     0.102592
# min                         0.000000                     0.015879
# 25%                         0.190037                     0.144129
# 50%                         0.260297                     0.201567
# 75%                         0.319006                     0.272119
# max                         0.644867                     0.612537
#
#        population_over_25_master  households_0_to_50,000  \
# count                3925.000000             3925.000000
# mean                    0.111100                0.381606
# std                     0.075028                0.171388
# min                     0.000000                0.000000
# 25%                     0.055526                0.251963
# 50%                     0.097544                0.349432
# 75%                     0.147220                0.487678
# max                     0.500000                0.924812
#
#        households_over_50,000  over_16_puplictransportation  \
# count             3925.000000                   3925.000000
# mean                 0.618394                      0.482882
# std                  0.171388                      0.177740
# min                  0.075188                      0.000000
# 25%                  0.512322                      0.334628
# 50%                  0.650568                      0.496174
# 75%                  0.748037                      0.627583
# max                  1.000000                      0.925049
#
#        log_accessibility_score
# count              3925.000000
# mean                  6.690790
# std                   2.860589
# min                   0.000000
# 25%                   6.709843
# 50%                   7.658114
# 75%                   8.352240
# max                  11.353815

# %%
fig, ax = plt.subplots(1, figsize=(12,12))

sns.heatmap(cluster_corr(regression_df.corr()))
# Out:
# <AxesSubplot:>

# %%
kf = KFold(n_splits=5)

X = regression_df[feature_col]
y = regression_df[target_col].values

# %%
plt.hist(y, bins=30)
plt.show()
print(np.array(y).mean(),np.array(y).std())
# Out:
# 0.4828822193406789 0.1777168695802589

# %%
feature_col
# Out:
# array(['accessibility_score', 'Average Commute to Work (In Min)',
#        'over_16_not_worked_home', 'over_16_non_polution_transport',
#        'over_16_non_public_transport', 'comute_time_less_30min',
#        'comute_time_more_30min', 'male_population',
#        'total_population_white', 'total_population_black',
#        'total_population_two_ormore_races', 'total_population_asian',
#        'female_population', 'population_over_25_no_highschool',
#        'population_over_25_highschool', 'population_over_25_bachelor',
#        'population_over_25_master', 'households_0_to_50,000',
#        'households_over_50,000', 'log_accessibility_score'], dtype='<U33')

# %%
X.head()
# Out:
#    accessibility_score Average Commute to Work (In Min)  \
# 0          6852.803169                               36
# 1         10457.932164                               29
# 2         12606.839514                               32
# 2         34449.760760                               32
# 2          2110.840364                               32
#
#    over_16_not_worked_home  over_16_non_polution_transport  \
# 0                 0.138546                        0.137631
# 1                 0.189198                        0.128395
# 2                 0.126891                        0.073950
# 2                 0.126891                        0.073950
# 2                 0.126891                        0.073950
#
#    over_16_non_public_transport  comute_time_less_30min  \
# 0                      0.102423                0.280293
# 1                      0.053086                0.382716
# 2                      0.178992                0.372269
# 2                      0.178992                0.372269
# 2                      0.178992                0.372269
#
#    comute_time_more_30min  male_population  total_population_white  \
# 0                0.581161         0.498846                0.847140
# 1                0.428086         0.485174                0.771594
# 2                0.500840         0.618509                0.701065
# 2                0.500840         0.618509                0.701065
# 2                0.500840         0.618509                0.701065
#
#    total_population_black  total_population_two_ormore_races  \
# 0                0.025391                           0.089254
# 1                0.038032                           0.084658
# 2                0.083222                           0.037949
# 2                0.083222                           0.037949
# 2                0.083222                           0.037949
#
#    total_population_asian  female_population  \
# 0                0.023083           0.501154
# 1                0.100774           0.514826
# 2                0.152463           0.381491
# 2                0.152463           0.381491
# 2                0.152463           0.381491
#
#    population_over_25_no_highschool  population_over_25_highschool  \
# 0                          0.024372                       0.050564
# 1                          0.023425                       0.025848
# 2                          0.008600                       0.046912
# 2                          0.008600                       0.046912
# 2                          0.008600                       0.046912
#
#    population_over_25_bachelor  population_over_25_master  \
# 0                     0.415424                   0.264824
# 1                     0.439688                   0.272213
# 2                     0.454261                   0.261142
# 2                     0.454261                   0.261142
# 2                     0.454261                   0.261142
#
#    households_0_to_50,000  households_over_50,000  log_accessibility_score
# 0                0.158179                0.841821                 8.832559
# 1                0.071804                0.928196                 9.255212
# 2                0.110024                0.889976                 9.442074
# 2                0.110024                0.889976                10.447286
# 2                0.110024                0.889976                 7.655315

# %%
preds = np.zeros(len(y))
coefs = np.zeros(len(X.columns))
for train_index, test_index in kf.split(regression_df):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y[train_index], y[test_index]
    scaler = StandardScaler()
    scaler = scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    reg = Ridge().fit(X_train_scaled, y_train)
    coefs += reg.coef_
    preds[test_index] = reg.predict(X_test_scaled)

coefs /= 5

# %%
idx = np.argsort(coefs)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))
ax[0].barh(feature_col[idx],coefs[idx])

ax[1].scatter(y, preds, alpha=0.6)
ax[1].plot([i for i in range(2)])
plt.show()
mean_squared_error(y, preds, squared=False), r2_score(y, preds)
# Out:
# (0.007550621349946088, 0.9981948717036125)

# %%
feature_col =  np.array([col for col in feature_col if col not in ['over_16_non_public_transport', 'over_16_non_polution_transport']])

kf = KFold(n_splits=5)

X = regression_df[feature_col].values
y = regression_df[target_col].values
preds = np.zeros(len(y))
coefs = np.zeros(len(feature_col))
for train_index, test_index in kf.split(regression_df):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    scaler = StandardScaler()
    scaler = scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    reg = Ridge().fit(X_train_scaled, y_train)
    coefs += reg.coef_
    preds[test_index] = reg.predict(X_test_scaled)

coefs /= 5

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))
idx = np.argsort(coefs)
ax[0].barh(feature_col[idx],coefs[idx])

ax[1].scatter(y, preds, alpha=0.6)
ax[1].plot([i for i in range(2)])
plt.show()
mean_squared_error(y, preds, squared=False), r2_score(y, preds)
# Out:
# (0.10925578776556076, 0.6220523962886086)

# %%
feature_col
# Out:
# array(['accessibility_score', 'Average Commute to Work (In Min)',
#        'over_16_not_worked_home', 'comute_time_less_30min',
#        'comute_time_more_30min', 'male_population',
#        'total_population_white', 'total_population_black',
#        'total_population_two_ormore_races', 'total_population_asian',
#        'female_population', 'population_over_25_no_highschool',
#        'population_over_25_highschool', 'population_over_25_bachelor',
#        'population_over_25_master', 'households_0_to_50,000',
#        'households_over_50,000', 'log_accessibility_score'], dtype='<U33')

# %%
feature_col =  np.array([col for col in feature_col if col not in ['over_16_non_public_transport', 'over_16_non_polution_transport', 'comute_time_less_30min', 'Average Commute to Work (In Min)', 'over_16_not_worked_home', 'comute_time_more_30min']])

kf = KFold(n_splits=5)

X = regression_df[feature_col].values
y = regression_df[target_col].values
preds = np.zeros(len(y))
coefs = np.zeros(len(feature_col))
for train_index, test_index in kf.split(regression_df):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    scaler = StandardScaler()
    scaler = scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    reg = Ridge().fit(X_train_scaled, y_train)
    coefs += reg.coef_
    preds[test_index] = reg.predict(X_test_scaled)

coefs /= 5

# %%
mse, r2 = mean_squared_error(y, preds, squared=False), r2_score(y, preds)

print(f"MSE:{mse}")
print(f"R^2 (coefficient of determination) regression score function.: {r2}")
fig, ax = plt.subplots(1,2, figsize=(10,8))
idx = np.argsort(coefs)

ax[0].set_title("Model weights")
ax[0].barh(feature_col[idx],coefs[idx])
ax[0].set_xlabel("Feature coefficient")

points = ax[1].scatter(y, preds, alpha=0.6, c = regression_df[f"log_{accessibility_metric}"])
ax[1].set_title("Ratio of people using public transport\nPredticed vs. True scores")
ax[1].plot([x for x in range(2)])
ax[1].set_xlabel("Predicted value")
ax[1].set_ylabel("True value")

plt.colorbar(points,ax=ax[1], label="Log accessibility score")

plt.show()
# Out:
# MSE:0.13050471296567237
# R^2 (coefficient of determination) regression score function.: 0.46074388048113235

# %% [markdown]
# # Visualizing the results

# %%
#Functions
def plot_scatter(df, metric_col, x='lng', y='lat', marker='.', alpha=1, figsize=(16,12), colormap='viridis', basemap=None, ax=None):  
    if not ax:
        fig, ax = plt.subplots(1, 1, figsize=figsize)
    df.plot.scatter(ax=ax, x=x, y=y, c="white", title=metric_col
                    , edgecolors='none', marker=marker, alpha=alpha, figsize=figsize);
    if basemap:
        ctx.add_basemap(ax=ax, crs=basemap)

    plt.xticks([], []); plt.yticks([], [])
    return ax

# %%
# Visualize Population Density per Census Tract
f, ax = plt.subplots(figsize=(14,14))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# ax = plot_scatter(stopsg, metric_col='cnt', y="stop_lat", x="stop_lon", marker='o', basemap=gdf.crs.to_string(),ax=ax)
gdf["Prediction_diff"] = y - preds
ax = gdf.plot(column="Prediction_diff",cmap='viridis',alpha=1,linewidth=0.05,ax=ax, legend=True)
ax = hex_df.plot.scatter(ax=ax, y="stop_lat", x="stop_lon", marker="o", color="black", alpha=.1, edgecolors='none')

plt.title('Prediction error')
# Out:
# Text(0.5, 1.0, 'Prediction error')

# %%
# Visualize Population Density per Census Tract
f, ax = plt.subplots(figsize=(14,14))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# ax = plot_scatter(stopsg, metric_col='cnt', y="stop_lat", x="stop_lon", marker='o', basemap=gdf.crs.to_string(),ax=ax)
gdf["Prediction_diff"] = y - preds
ax = gdf.plot(column="Prediction_diff",cmap='viridis',alpha=1,linewidth=0.05,ax=ax, legend=True)

plt.title('Prediction error')
# Out:
# Text(0.5, 1.0, 'Prediction error')

# %% [markdown]
# # Morans I reagrding accesibility

# %%
from splot.esda import (
    moran_scatterplot, lisa_cluster, plot_local_autocorrelation, plot_moran
)
from splot.libpysal import plot_spatial_weights
from pysal.lib import weights
import esda
plot_moran

# %%
len(gdf), gdf.GEOID.nunique()
# Out:
# (5152, 3390)

# %%
w_gdf = gdf[["GEOID", "geometry"]].merge(gdf.groupby("GEOID").accessibility_score.agg("sum").reset_index()).drop_duplicates()

# %%
w_gdf["log_accessibility_score"] = np.log(w_gdf["accessibility_score"] + 1)

# %%
w_gdf.head()
# Out:
#          GEOID                                           geometry  \
# 0  36047000700  POLYGON ((-74.00154 40.69279, -74.00132 40.693...
# 1  36047000900  POLYGON ((-73.99405 40.69090, -73.99374 40.691...
# 2  36047001100  POLYGON ((-73.99073 40.69305, -73.99045 40.693...
# 5  36047001300  POLYGON ((-73.99141 40.69863, -73.99131 40.699...
# 7  36047002000  POLYGON ((-74.01867 40.64741, -74.01809 40.647...
#
#    accessibility_score  log_accessibility_score
# 0          6852.803169                 8.832559
# 1         10457.932164                 9.255212
# 2         49167.440638                10.803007
# 5         11085.831522                 9.313513
# 7          1541.670859                 7.341271

# %%
w_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3390 entries, 0 to 5151
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   GEOID                    3390 non-null   object
#  1   geometry                 3390 non-null   geometry
#  2   accessibility_score      3390 non-null   float64
#  3   log_accessibility_score  3390 non-null   float64
# dtypes: float64(2), geometry(1), object(1)
# memory usage: 132.4+ KB

# %%
w = weights.Queen.from_dataframe(w_gdf, idVariable="GEOID")
# Out:
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There are 2 islands with ids: 36081091603, 36081107201.
#   warnings.warn(message)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
ax = w_gdf.loc[~w_gdf.GEOID.isin(w.islands), :].plot(color='black', ax=ax)
ax = w_gdf.loc[w_gdf.GEOID.isin(w.islands), :].plot(color='red', ax=ax)
plt.show()

# %%
w_gdf = w_gdf.loc[~w_gdf.GEOID.isin(w.islands), :].reset_index(drop=True)

# %%
# %time w = weights.Queen.from_dataframe(w_gdf, idVariable="GEOID")
# Out:
# CPU times: user 1.99 s, sys: 60.3 ms, total: 2.05 s
# Wall time: 2.06 s

# %%
lisa = esda.Moran_Local(w_gdf["log_accessibility_score"], w)

# %%
plot_local_autocorrelation(lisa, w_gdf, "log_accessibility_score", figsize=(16, 10))
# Out:
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/mapclassify/classifiers.py:238: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/mapclassify/classifiers.py:241: UserWarning: Warning: setting k to 4
#   Warn("Warning: setting k to %d" % k_q, UserWarning)
# (<Figure size 1152x720 with 3 Axes>,
#  array([<AxesSubplot:title={'center':'Moran Local Scatterplot'}, xlabel='Attribute', ylabel='Spatial Lag'>,
#         <AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
mi = esda.Moran(w_gdf["log_accessibility_score"], w)
mi.I, mi.p_sim
# Out:
# (0.29243710425563807, 0.001)

# %%
plot_moran(mi)
# Out:
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.29', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.29)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))

# %%
len(gdf), gdf.GEOID.nunique()
# Out:
# (5152, 3390)

# %%
w_gdf = gdf[["GEOID", "geometry"]].merge(gdf.groupby("GEOID").accessibility_score.agg("sum").reset_index()).drop_duplicates()

# %%
w_gdf["log_accessibility_score"] = np.log(w_gdf["accessibility_score"] + 1)

# %%
w_gdf.head()
# Out:
#          GEOID                                           geometry  \
# 0  36047000700  POLYGON ((-74.00154 40.69279, -74.00132 40.693...
# 1  36047000900  POLYGON ((-73.99405 40.69090, -73.99374 40.691...
# 2  36047001100  POLYGON ((-73.99073 40.69305, -73.99045 40.693...
# 5  36047001300  POLYGON ((-73.99141 40.69863, -73.99131 40.699...
# 7  36047002000  POLYGON ((-74.01867 40.64741, -74.01809 40.647...
#
#    accessibility_score  log_accessibility_score
# 0          6852.803169                 8.832559
# 1         10457.932164                 9.255212
# 2         49167.440638                10.803007
# 5         11085.831522                 9.313513
# 7          1541.670859                 7.341271

# %%
w_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 3390 entries, 0 to 5151
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   GEOID                    3390 non-null   object
#  1   geometry                 3390 non-null   geometry
#  2   accessibility_score      3390 non-null   float64
#  3   log_accessibility_score  3390 non-null   float64
# dtypes: float64(2), geometry(1), object(1)
# memory usage: 132.4+ KB

# %%
w = weights.Queen.from_dataframe(w_gdf, idVariable="GEOID")
# Out:
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 3 disconnected components.
#  There are 2 islands with ids: 36081091603, 36081107201.
#   warnings.warn(message)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
ax = w_gdf.loc[~w_gdf.GEOID.isin(w.islands), :].plot(color='black', ax=ax)
ax = w_gdf.loc[w_gdf.GEOID.isin(w.islands), :].plot(color='red', ax=ax)
plt.show()

# %%
w_gdf = w_gdf.loc[~w_gdf.GEOID.isin(w.islands), :].reset_index(drop=True)

# %%
# %time w = weights.Queen.from_dataframe(w_gdf, idVariable="GEOID")
# Out:
# CPU times: user 1.99 s, sys: 60.3 ms, total: 2.05 s
# Wall time: 2.06 s

# %%
lisa = esda.Moran_Local(w_gdf["log_accessibility_score"], w)

# %%
plot_local_autocorrelation(lisa, w_gdf, "log_accessibility_score", figsize=(16, 10))
# Out:
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/mapclassify/classifiers.py:238: UserWarning: Warning: Not enough unique values in array to form k classes
#   Warn(
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/mapclassify/classifiers.py:241: UserWarning: Warning: setting k to 4
#   Warn("Warning: setting k to %d" % k_q, UserWarning)
# (<Figure size 1152x720 with 3 Axes>,
#  array([<AxesSubplot:title={'center':'Moran Local Scatterplot'}, xlabel='Attribute', ylabel='Spatial Lag'>,
#         <AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
mi = esda.Moran(w_gdf["log_accessibility_score"], w)
mi.I, mi.p_sim
# Out:
# (0.29243710425563807, 0.001)

# %%
plot_moran(mi)
# Out:
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.29', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.29)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))

# %%
w_gdf = gdf.loc[gdf.COUNTYFP.isin(["081", "005", "047", "085", "061"])].copy()

# %%
len(w_gdf), w_gdf.GEOID.nunique()
# Out:
# (3925, 2216)

# %%
w_gdf = w_gdf[["GEOID", "geometry"]].merge(w_gdf.groupby("GEOID").accessibility_score.agg("sum").reset_index()).drop_duplicates()

# %%
w_gdf["log_accessibility_score"] = np.log(w_gdf["accessibility_score"] + 1)

# %%
w_gdf.head()
# Out:
#          GEOID                                           geometry  \
# 0  36047000700  POLYGON ((-74.00154 40.69279, -74.00132 40.693...
# 1  36047000900  POLYGON ((-73.99405 40.69090, -73.99374 40.691...
# 2  36047001100  POLYGON ((-73.99073 40.69305, -73.99045 40.693...
# 5  36047001300  POLYGON ((-73.99141 40.69863, -73.99131 40.699...
# 7  36047002000  POLYGON ((-74.01867 40.64741, -74.01809 40.647...
#
#    accessibility_score  log_accessibility_score
# 0          6852.803169                 8.832559
# 1         10457.932164                 9.255212
# 2         49167.440638                10.803007
# 5         11085.831522                 9.313513
# 7          1541.670859                 7.341271

# %%
w_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 2216 entries, 0 to 3924
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   GEOID                    2216 non-null   object
#  1   geometry                 2216 non-null   geometry
#  2   accessibility_score      2216 non-null   float64
#  3   log_accessibility_score  2216 non-null   float64
# dtypes: float64(2), geometry(1), object(1)
# memory usage: 86.6+ KB

# %%
w = weights.Queen.from_dataframe(w_gdf, idVariable="GEOID")
# Out:
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 4 disconnected components.
#  There are 2 islands with ids: 36081091603, 36081107201.
#   warnings.warn(message)

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
ax = w_gdf.loc[~w_gdf.GEOID.isin(w.islands), :].plot(color='black', ax=ax)
ax = w_gdf.loc[w_gdf.GEOID.isin(w.islands), :].plot(color='red', ax=ax)
plt.show()

# %%
w_gdf = w_gdf.loc[~w_gdf.GEOID.isin(w.islands), :].reset_index(drop=True)

# %%
# %time w = weights.Queen.from_dataframe(w_gdf, idVariable="GEOID")
# Out:
# CPU times: user 447 ms, sys: 16 ms, total: 463 ms
# Wall time: 465 ms
# /Users/viktortorpthomsen/opt/anaconda3/lib/python3.9/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)

# %%
lisa = esda.Moran_Local(w_gdf["log_accessibility_score"], w)

# %%
plot_local_autocorrelation(lisa, w_gdf, "log_accessibility_score", figsize=(16, 10))
# Out:
# (<Figure size 1152x720 with 3 Axes>,
#  array([<AxesSubplot:title={'center':'Moran Local Scatterplot'}, xlabel='Attribute', ylabel='Spatial Lag'>,
#         <AxesSubplot:>, <AxesSubplot:>], dtype=object))

# %%
mi = esda.Moran(w_gdf["log_accessibility_score"], w)
mi.I, mi.p_sim
# Out:
# (0.12944261783761923, 0.001)

# %%
plot_moran(mi)
# Out:
# (<Figure size 720x288 with 2 Axes>,
#  array([<AxesSubplot:title={'center':'Reference Distribution'}, xlabel='Moran I: 0.13', ylabel='Density'>,
#         <AxesSubplot:title={'center':'Moran Scatterplot (0.13)'}, xlabel='Attribute', ylabel='Spatial Lag'>],
#        dtype=object))
